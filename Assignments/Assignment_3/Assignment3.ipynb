# %%
import pandas as pd
import numpy as np

# %%
ds = pd.read_csv("/content/Mall_Customers.csv")

# %%
ds.head()
# Out:
#    CustomerID  Age  Annual Income (k$)  Spending Score (1-100)  Genre_Female  \
# 0           1   19                  15                      39         False
# 1           2   21                  15                      81         False
# 2           3   20                  16                       6          True
# 3           4   23                  16                      77          True
# 4           5   31                  17                      40          True
#
#    Genre_Male
# 0        True
# 1        True
# 2       False
# 3       False
# 4       False

# %%
X = ds.iloc[:, [0,1,2,4,5]]
y = ds.iloc[:, [3]]

# %%
X
# Out:
#      CustomerID  Age  Annual Income (k$)  Genre_Female  Genre_Male
# 0             1   19                  15         False        True
# 1             2   21                  15         False        True
# 2             3   20                  16          True       False
# 3             4   23                  16          True       False
# 4             5   31                  17          True       False
# ..          ...  ...                 ...           ...         ...
# 195         196   35                 120          True       False
# 196         197   45                 126          True       False
# 197         198   32                 126         False        True
# 198         199   32                 137         False        True
# 199         200   30                 137         False        True
#
# [200 rows x 5 columns]

# %%
y
# Out:
#      Spending Score (1-100)
# 0                        39
# 1                        81
# 2                         6
# 3                        77
# 4                        40
# ..                      ...
# 195                      79
# 196                      28
# 197                      74
# 198                      18
# 199                      83
#
# [200 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_Train, X_Test, y_Train, y_Test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = "linear", random_state = 0)

# %%
classifier.fit(X_Train, y_Train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='linear', random_state=0)

# %%
y_pred = classifier.predict(X_Test)

# %%
from sklearn import metrics

# %%
print("Mean absolute error: ", metrics.mean_absolute_error(y_Test, y_pred))
print("Mean squared error: ", metrics.mean_squared_error(y_Test, y_pred))
print("R2 score: ", metrics.r2_score(y_Test, y_pred))
# Out:
# Mean absolute error:  21.675
# Mean squared error:  1053.975
# R2 score:  -0.391404506990191
